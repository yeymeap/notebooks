# %% [markdown]
# # **1. Python előadás**
#
# Kétféle cella lehet: **Kód** vagy **Szöveg**
# A kód lehet egy vagy több utasítás

# %% [markdown]
# ## Minta program

# %% [markdown]
# Szükséges könyvtárak telepítése, <b>egyszer</b> elég futtatni.

# %%
# %pip install plotly
# %pip install pandas
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt
 
# line 1 points
x1 = [1,2,3,4]
y1 = [2,4,1,-1]
# plotting the line 1 points
plt.plot(x1, y1, label = "line 1")
 
# line 2 points
x2 = [1,2,3,4]
y2 = [4,1,3,12]
# plotting the line 2 points
plt.plot(x2, y2, label = "line 2")
 
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('Two lines on same graph!')
 
# show a legend on the plot
plt.legend()
 
# function to show the plot
plt.show()

# %% [markdown]
# ## Változók létrehozása

# %%
x = 5
y = "Hello, World!"

# %%
# Python program to declare variables
myNumber = 3
print(myNumber)
  
myNumber2 = 4.5
print(myNumber2)
  
myNumber ="helloworld"
print(myNumber)
# Out:
# 3
# 4.5
# helloworld

# %% [markdown]
# Identációs hiba
#
# <code>if 5 > 2:
# print("Five is greater than two!") <---
#     print("Five is greater than two!")</code>

# %%
# Python program to illustrate a list 
  
# creates a empty list
nums = [] 
  
# appending data in list
nums.append(21)
nums.append(40.5)
nums.append("String")
  
print(nums)
print(nums[0])
print(nums[1])
print(nums[2])
# Out:
# [21, 40.5, 'String']
# 21
# 40.5
# String

# %% [markdown]
# ## I/O - Input, Output

# %%
# Python program to illustrate getting input from user
name = input("Enter your name: ") 
  
# user entered the name 'harssh'
print("hello", name)
# Out:
# Enter your name:  Ferenc
# hello Ferenc

# %%
# Python3 program to get input from user
  
# accepting integer from the user
# the return type of input() function is string ,
# so we need to convert the input to integer
num1 = int(input("Enter num1: "))
num2 = int(input("Enter num2: "))
  
num3 = num1 * num2
print("Product is: ", num3)
# Out:
# Enter num1:  5
# Enter num2:  6
# Product is:  30

# %% [markdown]
# ## Feltételek

# %%
# Python program to illustrate selection statement
  
num1 = 14
if(num1>10):
    print("Num1 is greater than 10")
elif(num1>=5):
    print("Num1 is between 5 and 10")
else:
    print("Num1 is less than 5")
# Out:
# Num1 is greater than 10

# %% [markdown]
# ## Ciklusok

# %%
# Python program to illustrate a simple for loop
  
for step in range(5):    
    print(step)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Függvények

# %%
# Python program to illustrate functions
def hello():
    print("hello")
    print("hello again")

  
# calling function
hello()
# Out:
# hello
# hello again
